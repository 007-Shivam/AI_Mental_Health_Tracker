# %% [markdown]
# # IMPORTING DATA

# %%
import pandas as pd

file1 = 'C:/Users/Shivam 007/OneDrive/Desktop/mental-and-substance-use-as-share-of-disease.csv'
file2 = 'C:/Users/Shivam 007/OneDrive/Desktop/prevalence-by-mental-and-substance-use-disorder.csv'

df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)

display(df1.head())
display(df2.head())
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)
# 0                                           1.696670
# 1                                           1.734281
# 2                                           1.791189
# 3                                           1.776779
# 4                                           1.712986
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.228979
# 1                                           0.228120
# 2                                           0.227328
# ...

# %% [markdown]
# # MEARGING

# %%
df = pd.merge(df1, df2)

# %%
display(df.head())
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)  \
# 0                                           1.696670
# 1                                           1.734281
# 2                                           1.791189
# 3                                           1.776779
# 4                                           1.712986
#
#    Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.228979
# 1                                           0.228120
# 2                                           0.227328
# 3                                           0.226468
# 4                                           0.225567
#
#    Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)  \
# ...

# %% [markdown]
# # EXLORNG DATA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6840 entries, 0 to 6839
# Data columns (total 11 columns):
#  #   Column                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                           --------------  -----
#  0   Entity                                                                                           6840 non-null   object
#  1   Code                                                                                             6150 non-null   object
#  2   Year                                                                                             6840 non-null   int64
#  3   DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)  6840 non-null   float64
# ...

# %%
df.shape
# Out:
# (6840, 11)

# %% [markdown]
# # RENAMING THE COLUMNS

# %%
df = df.rename(columns={'DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)': 'DALYs',
                        'Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)': 'Schizophrenia',
                        'Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)': 'Bipolar disorder',
                        'Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)': 'Eating disorders',
                        'Prevalence - Anxiety disorders - Sex: Both - Age: Age-standardized (Percent)': 'Anxiety disorders',
                        'Prevalence - Drug use disorders - Sex: Both - Age: Age-standardized (Percent)': 'Drug use disorders',
                        'Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent)': 'Depressive disorders',
                        'Prevalence - Alcohol use disorders - Sex: Both - Age: Age-standardized (Percent)': 'Alcohol use disorders',
                        })

display(df.head())
# Out:
#         Entity Code  Year     DALYs  Schizophrenia  Bipolar disorder  \
# 0  Afghanistan  AFG  1990  1.696670       0.228979          0.721207
# 1  Afghanistan  AFG  1991  1.734281       0.228120          0.719952
# 2  Afghanistan  AFG  1992  1.791189       0.227328          0.718418
# 3  Afghanistan  AFG  1993  1.776779       0.226468          0.717452
# 4  Afghanistan  AFG  1994  1.712986       0.225567          0.717012
#
#    Eating disorders  Anxiety disorders  Drug use disorders  \
# 0          0.131001           4.835127            0.454202
# 1          0.126395           4.821765            0.447112
# 2          0.121832           4.801434            0.441190
# 3          0.117942           4.789363            0.435581
# 4          0.114547           4.784923            0.431822
#
#    Depressive disorders  Alcohol use disorders
# 0              5.125291               0.444036
# 1              5.116306               0.444250
# 2              5.106558               0.445501
# ...

# %% [markdown]
# # PREPROCESSING AND CLEANING THE DATA

# %%
df.isnull().sum()
# Out:
# Entity                     0
# Code                     690
# Year                       0
# DALYs                      0
# Schizophrenia              0
# Bipolar disorder           0
# Eating disorders           0
# Anxiety disorders          0
# Drug use disorders         0
# Depressive disorders       0
# Alcohol use disorders      0
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# Entity                   0
# Code                     0
# Year                     0
# DALYs                    0
# Schizophrenia            0
# Bipolar disorder         0
# Eating disorders         0
# Anxiety disorders        0
# Drug use disorders       0
# Depressive disorders     0
# Alcohol use disorders    0
# dtype: int64

# %%
columns_to_drop = ['Code']
df = df.drop(columns_to_drop, axis = 1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6150 entries, 0 to 6839
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Entity                 6150 non-null   object
#  1   Year                   6150 non-null   int64
#  2   DALYs                  6150 non-null   float64
#  3   Schizophrenia          6150 non-null   float64
#  4   Bipolar disorder       6150 non-null   float64
#  5   Eating disorders       6150 non-null   float64
#  6   Anxiety disorders      6150 non-null   float64
#  7   Drug use disorders     6150 non-null   float64
#  8   Depressive disorders   6150 non-null   float64
#  9   Alcohol use disorders  6150 non-null   float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 528.5+ KB

# %%
df.describe().T
# Out:
#                         count         mean       std          min  \
# Year                   6150.0  2004.500000  8.656145  1990.000000
# DALYs                  6150.0     4.793979  2.339855     0.215647
# Schizophrenia          6150.0     0.279364  0.046328     0.191621
# Bipolar disorder       6150.0     0.671429  0.256775     0.189344
# Eating disorders       6150.0     0.207104  0.153694     0.045425
# Anxiety disorders      6150.0     4.306032  1.184078     1.974823
# Drug use disorders     6150.0     0.709513  0.409264     0.225471
# Depressive disorders   6150.0     3.936882  0.951828     1.640902
# Alcohol use disorders  6150.0     1.543491  0.926478     0.319900
#
#                                25%          50%          75%          max
# Year                   1997.000000  2004.500000  2012.000000  2019.000000
# DALYs                     2.942782     4.598223     6.356361    13.761517
# Schizophrenia             0.250777     0.286491     0.303925     0.506018
# ...

# %%
df.shape
# Out:
# (6150, 10)

# %% [markdown]
# # VISUALIZING THE DATA

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### RELATIONAL PLOT

# %%
sns.relplot(x = "Schizophrenia", y = "Anxiety disorders", hue = "Year", data = df)

# %% [markdown]
# ### CATEGORIAL PLOT

# %%
sns.catplot(x = "Alcohol use disorders", y = "DALYs", hue = "Year", data = df)

# %% [markdown]
# ### HEATMAP

# %%
corrmat = df.corr()
f, ax = plt.subplots(figsize = (9, 6))
sns.heatmap(corrmat, vmax = .8, square = True)
# Out:
# C:\Users\Shivam 007\AppData\Local\Temp\ipykernel_2352\3417631138.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = df.corr()
# <Axes: >

# %%
plt.figure(figsize = (12,6))
sns.heatmap(df.corr(), annot = True, cmap = 'Reds')
plt.plot()
# Out:
# C:\Users\Shivam 007\AppData\Local\Temp\ipykernel_2352\3021613487.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True, cmap = 'Reds')
# []

# %% [markdown]
# ### JOINTLOT

# %%
sns.jointplot(data = df, x = 'Bipolar disorder', y = 'Drug use disorders', kind = 'reg')
plt.show()

# %% [markdown]
# ### PAIRPLOT

# %%
sns.set_palette("Reds")
sns.pairplot(df, corner = True)
plt.show()

# %% [markdown]
# # DIVIDING DATA IN TRAINING DATA & TESTING DATA

# %%
from sklearn.preprocessing import LabelEncoder

l = LabelEncoder()

for i in df.columns:
    if df[i].dtype == 'object':
        df[i] = l.fit_transform(df[i])

# %%
X = df.drop(['DALYs',
            'Schizophrenia',
            'Bipolar disorder',
            'Eating disorders',
            'Anxiety disorders',
            'Drug use disorders',
            'Depressive disorders',
            'Alcohol use disorders',
            ], axis = 1)

y = df[['DALYs',
        'Schizophrenia',
        'Bipolar disorder',
        'Eating disorders',
        'Anxiety disorders',
        'Drug use disorders',
        'Depressive disorders',
        'Alcohol use disorders',
        ]]

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size = 0.2, random_state = 2)

# %%
print("Training data shape:")
print(xtrain.shape)  # Shape of the training features
print(ytrain.shape)  # Shape of the training target variables

print("\nTesting data shape:")
print(xtest.shape)  # Shape of the testing features
print(ytest.shape)  # Shape of the testing target variables
# Out:
# Training data shape:
# (4920, 2)
# (4920, 8)
#
# Testing data shape:
# (1230, 2)
# (1230, 8)

# %% [markdown]
# # EVALUATING THE LINEAR RERESSION MODEL

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Initialize the Linear Regression model
model = LinearRegression()

# Train the model
model.fit(xtrain, ytrain)

# model evaluation for training set
ytrain_pred = model.predict(xtrain)
mse = mean_squared_error(ytrain, ytrain_pred)
rmse = (np.sqrt(mse))
r2 = r2_score(ytrain, ytrain_pred)

print("Training Set : Linear Regression model")
print("*****************************************")
print('MSE \t = {}'.format(mse))
print('RMSE \t = {}'.format(rmse))
print('R2 score = {}\n'.format(r2))
print("=======================================")

# model evaluation for testing set
ytest_pred = model.predict(xtest)
mse = mean_squared_error(ytest, ytest_pred)
rmse = (np.sqrt(mean_squared_error(ytest, ytest_pred)))
r2 = r2_score(ytest, ytest_pred)

print("\nTesting Set : Linear Regression model")
print("*****************************************")
print('MSE \t = {}'.format(mse))
print('RMSE \t = {}'.format(rmse))
print('R2 score = {}'.format(r2))
# Out:
# Training Set : Linear Regression model
# *****************************************
# MSE 	 = 1.0824636529452798
# RMSE 	 = 1.0404151349078308
# R2 score = 0.011544160072103571
#
# ...
#
# Testing Set : Linear Regression model
# *****************************************
# MSE 	 = 1.0890824104468777
# RMSE 	 = 1.0435911126714705
# R2 score = 0.01034692046480204

# %% [markdown]
# The linear regression model's performance for both the training and testing sets is not particularly strong. The mean squared error (MSE) and root mean squared error (RMSE) indicate relatively high levels of error, while the R2 score suggests that only a small portion of the variance in the data is explained by the model.

# %% [markdown]
# # EVALUATING THE RANDOM FOREST RERESSION MODEL

# %%
from sklearn.ensemble import RandomForestRegressor

# Initialize the Random Forest Regression MODEL
rf = RandomForestRegressor()

# Train the model
rf.fit(xtrain, ytrain)

# model evaluation for training set
ytrain_pred = rf.predict(xtrain)
mse = mean_squared_error(ytrain, ytrain_pred)
rmse = (np.sqrt(mse))
r2 = r2_score(ytrain, ytrain_pred)

print("Training Set : Random Forest Regression MODEL")
print("***********************************************")
print('MSE \t = {}'.format(mse))
print('RMSE \t = {}'.format(rmse))
print('R2 score = {}\n'.format(r2))
print("=======================================")

# model evaluation for testing set
ytest_pred = rf.predict(xtest)
mse = mean_squared_error(ytest, ytest_pred)
rmse = (np.sqrt(mean_squared_error(ytest, ytest_pred)))
r2 = r2_score(ytest, ytest_pred)

print("\nTesting Set : Random Forest Regression MODEL")
print("************************************************")
print('MSE \t = {}'.format(mse))
print('RMSE \t = {}'.format(rmse))
print('R2 score = {}'.format(r2))
# Out:
# Training Set : Random Forest Regression MODEL
# ***********************************************
# MSE 	 = 0.0004308914076461858
# RMSE 	 = 0.02075792397245413
# R2 score = 0.9998517463880269
#
# ...
#
# Testing Set : Random Forest Regression MODEL
# ************************************************
# MSE 	 = 0.0025076661667254
# RMSE 	 = 0.05007660298707771
# R2 score = 0.9990651554540689

# %% [markdown]
# The RandomForestRegressor model shows excellent performance on both the training and testing sets. It achieves a high R2 score of around 0.999, indicating that it can explain a significant portion of the variance in the target variable. The mean squared error (MSE) and root mean squared error (RMSE) values are also low, suggesting good predictive accuracy. Overall, the model demonstrates strong performance in predicting the target variable.

# %% [markdown]
# # EVALUATING THE DECISION TREE REGRESSION MODEL

# %%
from sklearn.tree import DecisionTreeRegressor

# Initialize the Decision Tree Regression model
dt = DecisionTreeRegressor()

# Train the model
dt.fit(xtrain, ytrain)

# model evaluation for training set
ytrain_pred = dt.predict(xtrain)
mse = mean_squared_error(ytrain, ytrain_pred)
rmse = (np.sqrt(mse))
r2 = r2_score(ytrain, ytrain_pred)

print("Training Set : Decision Tree Regression model")
print("************************************************")
print('MSE \t = {}'.format(mse))
print('RMSE \t = {}'.format(rmse))
print('R2 score = {}\n'.format(r2))
print("=======================================")

# model evaluation for testing set
ytest_pred = dt.predict(xtest)
mse = mean_squared_error(ytest, ytest_pred)
rmse = (np.sqrt(mean_squared_error(ytest, ytest_pred)))
r2 = r2_score(ytest, ytest_pred)

print("\nTesting Set : Decision Tree Regression model")
print("*************************************************")
print('MSE \t = {}'.format(mse))
print('RMSE \t = {}'.format(rmse))
print('R2 score = {}'.format(r2))
# Out:
# Training Set : Decision Tree Regression model
# ************************************************
# MSE 	 = 0.0
# RMSE 	 = 0.0
# R2 score = 1.0
#
# ...
#
# Testing Set : Decision Tree Regression model
# *************************************************
# MSE 	 = 0.003603096676482063
# RMSE 	 = 0.06002580009031169
# R2 score = 0.9987732261903594

# %% [markdown]
# The DecisionTreeRegressor model performed very well on both the training and testing sets. The MSE, RMSE, and R2 scores for the training set are all 0, which indicates that the model perfectly predicted the training data. The MSE and RMSE scores for the testing set are very small, and the R2 score is very close to 1, which indicates that the model also performed well on the testing data. Overall, the DecisionTreeRegressor model is a good choice for this regression task.

# %% [markdown]
# ## From the above 3 Models, RANDOM FOREST RERESSION MODEL & DECISION TREE REGRESSION MODEL will be a good choice for the given data files.
